# %%
print("hello world")
# Out:
# hello world

# %%
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
# Out:
# d:\Mentor\Ai_Powered_ChatBot\ai_powered\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
# Load .env file
load_dotenv()
# Out:
# True

# %%
# Verify key is loaded
api_key = os.getenv("GROQ_API_KEY")

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.3,
    api_key=api_key
)

# %%
llm2 = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.3,
    api_key=api_key
)

# %%
response = llm2.invoke([
    HumanMessage(content="Define is data scientist, In two lines.")
])

print(response.content)
# Out:
# A data scientist is a professional who collects, analyzes, and interprets complex data to gain insights and make informed decisions, often using machine learning and statistical techniques. Their role involves extracting valuable patterns, trends, and predictions from large datasets to drive business strategy, optimize operations, and solve real-world problems.
